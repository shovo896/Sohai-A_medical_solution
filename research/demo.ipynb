# %%
print("Ok")
# Out:
# Ok

# %%
# %pwd
# Out:
# '/Users/imac/Sohai/research'

# %%
import os
##os..chdir("../")

# %%
from langchain_community.document_loaders import PyPDFLoader, DirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter

# %%
def load_pdf_files(data):
    loader = DirectoryLoader(data, glob="**/*.pdf", show_progress=True, silent_errors=True)
    documents = loader.load()
    return documents

# %%
extracted_docs = load_pdf_files("../data")
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]Error loading file ../data/Medical_book.pdf: unstructured package not found, please install it with `pip install unstructured`
# 100%|██████████| 1/1 [00:00<00:00, 369.97it/s]
